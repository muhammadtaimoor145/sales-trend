# %%
import pandas as pd

# %%
data=pd.read_csv("Amazon.csv") # READING FILE FROM PANDAS
# Out:
# c:\python 3.9\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head(5)
# Out:
#       CustKey     DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10000481.0   4/30/2017          -237.91   2017/04/30        100012.0
# 1  10002220.0   7/14/2017           368.79   2017/07/14        100233.0
# 2  10002220.0  10/17/2017           109.73   2017/10/17        116165.0
# 3  10002489.0    6/3/2017          -211.75   2017/06/03        100096.0
# 4  10004516.0   5/27/2017         96627.94   2017/05/27        103341.0
#
#   Item Class Item Number                             Item  Line Number  \
# 0        NaN         NaN                 Urban Large Eggs       2000.0
# 1        P01       20910               Moms Sliced Turkey       1000.0
# 2        P01       38076  Cutting Edge Foot-Long Hot Dogs       1000.0
# 3        NaN         NaN                         Kiwi Lox       1000.0
# 4        P01       60776             High Top Sweet Onion       1000.0
#
#    List Price  ...  Sales Cost Amount Sales Margin Amount  Sales Price  \
# ...

# %%
data.isnull().sum() # CHECKING NULL VALUES. HOW MUCH NULL VALUES WE HAVE IN OUR DATA
# Out:
# CustKey                               253
# DateKey                               253
# Discount Amount                       255
# Invoice Date                          253
# Invoice Number                        253
# Item Class                           8542
# Item Number                           294
# Item                                  253
# Line Number                           253
# List Price                            253
# Order Number                          253
# Promised Delivery Date                253
# Sales Amount                          253
# Sales Amount Based on List Price      253
# Sales Cost Amount                     253
# Sales Margin Amount                   253
# Sales Price                           254
# Sales Quantity                        253
# Sales Rep                             253
# U/M                                   253
# Unnamed: 20                         65535
# Unnamed: 21                         65531
# ...

# %%
col=data.columns
print(('Number of columns :', len(col)))
data.columns
# Out:
# ('Number of columns :', 24)
# Index(['CustKey', 'DateKey', 'Discount Amount', 'Invoice Date',
#        'Invoice Number', 'Item Class', 'Item Number', 'Item', 'Line Number',
#        'List Price', 'Order Number', 'Promised Delivery Date', 'Sales Amount',
#        'Sales Amount Based on List Price', 'Sales Cost Amount',
#        'Sales Margin Amount', 'Sales Price', 'Sales Quantity', 'Sales Rep',
#        'U/M', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull(),yticklabels=False) # GRAPHICALLY SHOW THE NULL VALUES
# Out:
# <AxesSubplot:>

# %%
data.describe() # DESCRIBING THE WHOLE DATA
# Out:
#             CustKey  Discount Amount  Invoice Number    Line Number  \
# count  6.528200e+04     65280.000000    65282.000000   65282.000000
# mean   1.001770e+07      1855.574835   216223.662020   23713.849790
# std    7.176148e+03      9037.140888    94992.281866   32664.024053
# min    1.000045e+07   -255820.800000   100012.000000    1000.000000
# 25%    1.001272e+07       246.037500   117931.000000    3000.000000
# 50%    1.001966e+07       441.760000   222869.500000   12000.000000
# 75%    1.002351e+07       999.760000   314318.750000   32000.000000
# max    1.002758e+07    343532.660000   332842.000000  344000.000000
#
#          List Price   Order Number   Sales Amount  \
# count  65282.000000   65282.000000   65282.000000
# mean     514.693380  180583.064352    2852.038373
# std      449.189182   67593.871116   15164.342107
# min        0.000000  100838.000000     200.010000
# 25%      181.560000  115321.000000     308.387500
# ...

# %%
x=data.fillna(data.mean())

# %%
x.isnull().sum()
# Out:
# CustKey                                 0
# DateKey                               253
# Discount Amount                         0
# Invoice Date                          253
# Invoice Number                          0
# Item Class                           8542
# Item Number                           294
# Item                                  253
# Line Number                             0
# List Price                              0
# Order Number                            0
# Promised Delivery Date                253
# Sales Amount                            0
# Sales Amount Based on List Price        0
# Sales Cost Amount                       0
# Sales Margin Amount                     0
# Sales Price                             0
# Sales Quantity                          0
# Sales Rep                               0
# U/M                                   253
# Unnamed: 20                         65535
# Unnamed: 21                         65531
# ...

# %% [markdown]
# STILL WE HAVE LOT OF NULL VALUES AVAILABLE IN OUR DATA. BUT WE WILL MANAGE IT LATER. OUR MAIN CONCERN IS TO FIND SALES INSIGHTS.THERE ARE NO NULL VALUES IN SALES. SO NOW WHAT WILL DO IS TO CREATE NEW CSV FILE AND LOAD THAT INTO POWER BI.

# %%
x.to_csv("NEW AMAZON.csv",index=False) # SO WE HAVE CREATED. NOW WE WILL GO TO POWER BI, WILL DO SOME ETL AND MAKE A DASHOBOARD.
